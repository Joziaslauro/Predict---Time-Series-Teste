# %% [markdown]
# <a href="https://colab.research.google.com/github/Joziaslauro/Predict---Time-Series-Teste/blob/master/An%C3%A1lise_e_Visualiza%C3%A7%C3%A3o_de_Dados_da_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
covid_br = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_2021_Parte2_30jul2021.csv', sep=';' )

# %%
covid_br
# Out:
#               regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0             Brasil    NaN  ...             1180443.0                     NaN
# 1             Brasil    NaN  ...             1170937.0                     NaN
# 2             Brasil    NaN  ...             1176166.0                     NaN
# 3             Brasil    NaN  ...             1184630.0                     NaN
# 4             Brasil    NaN  ...             1162515.0                     NaN
# ...              ...    ...  ...                   ...                     ...
# 168565  Centro-Oeste     DF  ...                   NaN                     1.0
# 168566  Centro-Oeste     DF  ...                   NaN                     1.0
# 168567  Centro-Oeste     DF  ...                   NaN                     1.0
# 168568  Centro-Oeste     DF  ...                   NaN                     1.0
# 168569  Centro-Oeste     DF  ...                   NaN                     1.0
#
# ...

# %%
covid_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168570 entries, 0 to 168569
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  168570 non-null  object
#  1   estado                  168540 non-null  object
#  2   municipio               167100 non-null  object
#  3   coduf                   168570 non-null  int64
#  4   codmun                  167730 non-null  float64
#  5   codRegiaoSaude          167100 non-null  float64
#  6   nomeRegiaoSaude         167100 non-null  object
#  7   data                    168570 non-null  object
#  8   semanaEpi               168570 non-null  int64
#  9   populacaoTCU2019        167940 non-null  float64
#  10  casosAcumulado          168570 non-null  int64
#  11  casosNovos              168570 non-null  int64
#  12  obitosAcumulado         168570 non-null  int64
#  13  obitosNovos             168570 non-null  int64
# ...

# %%
covid_br[covid_br.estado.isna()]
# Out:
#     regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0   Brasil    NaN  ...             1180443.0                     NaN
# 1   Brasil    NaN  ...             1170937.0                     NaN
# 2   Brasil    NaN  ...             1176166.0                     NaN
# 3   Brasil    NaN  ...             1184630.0                     NaN
# 4   Brasil    NaN  ...             1162515.0                     NaN
# 5   Brasil    NaN  ...             1115726.0                     NaN
# 6   Brasil    NaN  ...             1065477.0                     NaN
# 7   Brasil    NaN  ...             1027827.0                     NaN
# 8   Brasil    NaN  ...             1009729.0                     NaN
# 9   Brasil    NaN  ...             1009534.0                     NaN
# 10  Brasil    NaN  ...             1005741.0                     NaN
# 11  Brasil    NaN  ...              968140.0                     NaN
# 12  Brasil    NaN  ...              906084.0                     NaN
# ...

# %%
covid_br[covid_br.estado.isna()].casosNovos.plot()

# %%
covid_br[covid_br.estado.isna()].casosAcumulado.plot()

# %%
covid_br[covid_br.estado.isna()].casosNovos.plot()

# %%
covid_br.describe()
# Out:
#                coduf  ...  interior/metropolitana
# count  168570.000000  ...           167100.000000
# mean       32.360384  ...                0.069300
# std         9.873325  ...                0.253964
# min        11.000000  ...                0.000000
# 25%        25.000000  ...                0.000000
# 50%        31.000000  ...                0.000000
# 75%        41.000000  ...                0.000000
# max        76.000000  ...                1.000000
#
# [8 rows x 12 columns]

# %%
covid_br.describe(include='all')
# Out:
#           regiao  estado  ... emAcompanhamentoNovos  interior/metropolitana
# count     168570  168540  ...          3.000000e+01           167100.000000
# unique         6      27  ...                   NaN                     NaN
# top     Nordeste      MG  ...                   NaN                     NaN
# freq       54360   25650  ...                   NaN                     NaN
# mean         NaN     NaN  ...          9.039120e+05                0.069300
# std          NaN     NaN  ...          1.673190e+05                0.253964
# min          NaN     NaN  ...          7.136010e+05                0.000000
# 25%          NaN     NaN  ...          7.640262e+05                0.000000
# 50%          NaN     NaN  ...          8.169595e+05                0.000000
# 75%          NaN     NaN  ...          1.023302e+06                0.000000
# max          NaN     NaN  ...          1.184630e+06                1.000000
#
# [11 rows x 17 columns]

# %%
covid_br.sort_values(by=['obitosNovos']).head(20)
# Out:
#               regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 17491       Nordeste     MA  ...                   NaN                     0.0
# 17400       Nordeste     MA  ...                   NaN                     0.0
# 19964       Nordeste     MA  ...                   NaN                     1.0
# 18343       Nordeste     MA  ...                   NaN                     1.0
# 20024       Nordeste     MA  ...                   NaN                     1.0
# 101255       Sudeste     SP  ...                   NaN                     1.0
# 19440       Nordeste     MA  ...                   NaN                     1.0
# 11876          Norte     TO  ...                   NaN                     0.0
# 14155          Norte     TO  ...                   NaN                     0.0
# 17431       Nordeste     MA  ...                   NaN                     0.0
# 15271       Nordeste     MA  ...                   NaN                     0.0
# ...

# %%
covid_br[covid_br.estado.isna()].obitosNovos.plot

# %%
covid_br.sort_values(by=['obitosNovos']).head
# Out:
# <bound method NDFrame.head of          regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 17491  Nordeste     MA  ...                   NaN                     0.0
# 17400  Nordeste     MA  ...                   NaN                     0.0
# 19964  Nordeste     MA  ...                   NaN                     1.0
# 18343  Nordeste     MA  ...                   NaN                     1.0
# 20024  Nordeste     MA  ...                   NaN                     1.0
# ...         ...    ...  ...                   ...                     ...
# 7        Brasil    NaN  ...             1027827.0                     NaN
# 6        Brasil    NaN  ...             1065477.0                     NaN
# 5        Brasil    NaN  ...             1115726.0                     NaN
# 1        Brasil    NaN  ...             1170937.0                     NaN
# 0        Brasil    NaN  ...             1180443.0                     NaN
#
# [168570 rows x 17 columns]>

# %%
covid_br[covid_br.municipio == 'Paratinga'].obitosNovos.value_counts()
# Out:
# 0    26
# 1     3
# 2     1
# Name: obitosNovos, dtype: int64

# %%
covid_br[covid_br.municipio == 'Paratinga'].data.value_counts()
# Out:
# 2021-07-23    1
# 2021-07-13    1
# 2021-07-30    1
# 2021-07-16    1
# 2021-07-18    1
# 2021-07-11    1
# 2021-07-05    1
# 2021-07-14    1
# 2021-07-25    1
# 2021-07-20    1
# 2021-07-10    1
# 2021-07-01    1
# 2021-07-19    1
# 2021-07-15    1
# 2021-07-02    1
# 2021-07-28    1
# 2021-07-21    1
# 2021-07-03    1
# 2021-07-17    1
# 2021-07-07    1
# 2021-07-22    1
# 2021-07-04    1
# 2021-07-12    1
# 2021-07-24    1
# 2021-07-26    1
# 2021-07-29    1
# 2021-07-06    1
# 2021-07-27    1
# 2021-07-08    1
# 2021-07-09    1
# Name: data, dtype: int64

# %%
covid_br[covid_br.municipio == 'Paratinga'].duplicated().sum()
# Out:
# 0
